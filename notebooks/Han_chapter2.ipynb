# %% [markdown]
# <a href="https://colab.research.google.com/github/amirabbasgashtil/data-mining-course/blob/main/notebooks/Han_chapter2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Han- Data, Measurement and Data preprocessing- chapter2

# %% [markdown]
# ## Data types
#
#
# 1.   Nominal attributes
# 2.   Binary attributes
# 3.   Ordinal attributes
# 4.   Numeric attributes
# 5.   Discrete vs continous attributes

# %% [markdown]
# ### Nominal attributes
# The values of a **nominal attribute** are symbols or names of things, nominal attributes are also referred to as **categorical**. The values do not have any meaningful order.

# %%
import pandas as pd
data = {
    'Names': ['ali', 'sina', 'mohammad'],
    'Cities': ['Tehran', 'Shiraz', 'Rasht'],
    'Universities': ['IUST', 'SUT', 'SBU']
}

df = pd.DataFrame(data)
df.head()
# Out:
#       Names  Cities Universities
# 0       ali  Tehran         IUST
# 1      sina  Shiraz          SUT
# 2  mohammad   Rasht          SBU

# %% [markdown]
# ### Binary attributes
# A **binary attribute** is a nominal attribute with only two categories or states: 0 or 1, where 0 typically
# means that the attribute is absent, and 1 means that it is present. Binary attributes are referred to as
# Boolean if the two states correspond to *true* and *false*.

# %%
data = {
    'courses': ['data-mining', 'data-structures', 'ml-theory'],
    'is_offered_this_term': [1, 0, 1]
}
df = pd.DataFrame(data)
df.head()
# Out:
#            courses  is_offered_this_term
# 0      data-mining                     1
# 1  data-structures                     0
# 2        ml-theory                     1

# %% [markdown]
# ### Ordinal attributes
# An **ordinal attribute** is an attribute with possible values that have a meaningful order or ranking among
# them, but the magnitude between successive values is not known.

# %%
data = {
    'students': ['rahimi', "jamshidi", "rezaei"],
    'course_overview': ['didn\'t pass', 'not bad', 'well']
}

df = pd.DataFrame(data)
df.head()
# Out:
#    students course_overview
# 0    rahimi     didn't pass
# 1  jamshidi         not bad
# 2    rezaei            well

# %% [markdown]
# ### numeric attributes
# A **numeric attribute** is quantitative; it is a measurable quantity, represented in integer or real values. Numeric attributes can be interval-scaled or ratio-scaled.

# %%
data = {
    'product' :['phone', 'laptop', 'mouse'],
    'price_in_dollars': [999, 1499, 99],
    'discount_in_percent': [5, 7, 2]
}
df = pd.DataFrame(data)

print(df.describe())
df['normalized_price'] = (df['price_in_dollars'] - df['price_in_dollars'].mean()) / df['price_in_dollars'].std()
df.head()
# Out:
#        price_in_dollars  discount_in_percent
# count          3.000000             3.000000
# mean         865.666667             4.666667
# std          709.459888             2.516611
# min           99.000000             2.000000
# 25%          549.000000             3.500000
# 50%          999.000000             5.000000
# 75%         1249.000000             6.000000
# max         1499.000000             7.000000
#   product  price_in_dollars  discount_in_percent  normalized_price
# 0   phone               999                    5          0.187936
# 1  laptop              1499                    7          0.892698
# 2   mouse                99                    2         -1.080634

# %% [markdown]
# ### Discrete vs Continous attribute
# A **discrete attribute** has a finite or countably infinite set of values, which may or may not be represented as integers.
#
# If an attribute is not discrete, it is **continuous**.

# %%
import random
data = {
    'classes_size' : [100, 50, 60, 30], # discrete
    'student_heights': [i for i in range(170, 199)]  # continous
}
df = pd.DataFrame(data['classes_size'])
df['student_heights'] =  data['student_heights'][:4]
df.head()
# Out:
#      0  student_heights
# 0  100              170
# 1   50              171
# 2   60              172
# 3   30              173

# %% [markdown]
# ## statistics of data
#
#
# 1.   measuring centeral tendency
# 2.   measuring dipersion of data
# 3.   covariance and corelation
# 4.   Graphic displays of basic statistics of data

# %% [markdown]
# ### measuring centeral tendency
#
#
# *   **mean** = sum of observes / number of observes
# *   **median** = middle value in a set of ordered data values
# *   **mode** = value that occurs most frequently compared to all neighboring values in the set.
# *   **midrange** = average of the largest and smallest values in the set.

# %%
import numpy as np
salary_data_in_dollars_monthly = np.array([1000, 1500, 900, 750, 500, 2000, 1500, 1200, 1100, 450])

# mean
mean = np.sum(salary_data_in_dollars_monthly) / np.size(salary_data_in_dollars_monthly)

# median
salary_data_in_dollars_monthly.sort()
median = salary_data_in_dollars_monthly[np.size(salary_data_in_dollars_monthly) // 2]

# mode
dict = {}
for item in salary_data_in_dollars_monthly:
  if item in dict:
    dict[item] += 1
  else:
    dict.update({item : 1})
mode = max(zip(dict.values(), dict.keys()))[1]

# midrange
mid_range = (salary_data_in_dollars_monthly[0] + salary_data_in_dollars_monthly[np.size(salary_data_in_dollars_monthly) - 1]) / 2

print(f"mean of data is {mean}")
print(f"median of data is {median}")
print(f"mode of data is {mode}")
print(f"mid range of data is {mid_range}")

''' by using numpy and scipy :
import numpy as np
import scipy
  mean = np.mean(array)
  median = np.median(array)
  mode = scipy.stats.mode(arr)
  '''
# Out:
# mean of data is 1090.0
# median of data is 1100
# mode of data is 1500
# mid range of data is 1225.0
# ' by using numpy and scipy : \nimport numpy as np\nimport scipy\n  mean = np.mean(array)\n  median = np.median(array)\n  mode = scipy.stats.mode(arr)\n  '

# %% [markdown]
# ### measuring dipersion of data
#
# *   Range, quartiles
# *   boxplot, outliers
# *   variance and standard deviation

# %%
# range and quartiles
import numpy as np

arr = np.array([10, 4, 23, 54, 79, 9, 67, 35, 3, 64])

range = np.ptp(arr) # difference maximum between minimum of data
print(f"range is: {range}")

quantile = np.quantile(arr, 0.25) # computes the q-th quantile of data along the specified axis
print(f"quantile is: {quantile}")
# Out:
# range is: 76
# quantile is: 9.25

# %%
# boxplot and outliers

import matplotlib.pyplot as plt

np.random.seed(10)
data = np.random.normal(100, 20, 200)
fig = plt.figure(figsize =(2, 3))
plt.boxplot(data)
plt.show()

# %%
# varince and standard deviation

import numpy as np
arr = np.array([10, 4, 23, 54, 79, 9, 67, 35, 3, 64])

var = np.var(arr)
std = np.std(arr)
print(f"variance of data is :{var} and standard deviation is: {std}")
# Out:
# variance of data is :759.1600000000001 and standard deviation is: 27.55285829092873

# %% [markdown]
# ### covariance and corelation analysis
#
#
# *   covariance of numeric data
# *   correlation coefficient for numeric data

# %% [markdown]
# $covariance(A,B) = E((A - A̅) (B - B̅)) = ((Σ((a_i - A̅)(b_i - B̅))) / n)$

# %%
import numpy as np
a = np.array([12, 34, 46, 43, 32, 17, 65, 76])
b = np. array([45, 34, 32, 54, 67, 87, 45, 54])

cov_matrix = np.cov(a, b)
cov_matrix
# Out:
# array([[ 482.26785714, -119.89285714],
#        [-119.89285714,  325.64285714]])

# %% [markdown]
# **correlation coefficients for numeric data**:
#
#
# ![Screenshot 2024-10-23 161742.png](data:image/png;base64,...)

# %%
import numpy as np
a = np.array([12, 34, 46, 43, 32, 17, 65, 76])
b = np. array([45, 34, 32, 54, 67, 87, 45, 54])

correlation_coef = np.corrcoef(a, b)
correlation_coef
# Out:
# array([[ 1.        , -0.30253691],
#        [-0.30253691,  1.        ]])

# %% [markdown]
# **chi 2** test in my github please check : [**chi2-test-for-independencs**](https://github.com/amirabbasgashtil/statistics/blob/main/12-chi2-test-for-independencs.ipynb)

# %% [markdown]
# ### graphic displays of basic statistics of data
#
#
# *   histogram
# *   scatter plot

# %%
# histogram
import numpy as np
import matplotlib.pyplot as plt

data = np.random.normal(0, 0.1, 100)
plt.hist(data)
plt.show()

# %%
# scatter

import matplotlib.pyplot as plt
import numpy as np

# Example datasets
x = np.random.normal(0, 0.4, 100)
y = 2 * x + np.random.normal(10, 0.4, 100)
plt.scatter(x, y, color='black', alpha=0.7)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %% [markdown]
# ## similarity and distance measures
#
#
# 1.   Data matrix vs dissimilarity matrix
# 2.   proximity measures for nominal attributes
# 3.   proximity measures for binary attributes
# 4.   dissimilarity for numeric data: minkowski distance
# 5.   proximity measures for ordinal attributes
# 6.   dissimilarity for attributes of mixed type
# 7.   cosine similarity
# 8.   measuring similar distributions
# 9.   Capturing hidden semantics in similarity measures

# %% [markdown]
# ### Data matrix vs dissimilarity matrix
# **Data matrix** stores the n data objects in the form
# of a relational table or an n-by-p matrix (n objects * p attributes).
#
# **dissimilarity matrix** stores a collection of proximities
# that are available for all pairs of n objects. It is often represented by an n-by-n table.
#
# d(i, j) is the measured dissimilarity or “difference” between objects i and j . In general,
# d(i, j) is a nonnegative number that is close to 0 when objects i and j are highly similar or “near”
# each other, and becomes larger the more they differ.

# %%
# data matrix
import pandas as pd

data_matrix = {
    "feature1" : [10, 12, 34 ,45, 54],
    "feature2" : [10, 20, 30, 40, 50]
}
# now number of features = 2 and number of observations = 5
# data matrix is 5*2
df = pd.DataFrame(data_matrix)
df
# Out:
#    feature1  feature2
# 0        10        10
# 1        12        20
# 2        34        30
# 3        45        40
# 4        54        50

# %%
# dissimilarity matrix
from scipy.spatial.distance import pdist, squareform
import pandas as pd

data_matrix = {
    'Feature1': [10, 12, 34, 45, 54],
    'Feature2': [10, 20, 30, 40, 50]
}

df = pd.DataFrame(data_matrix)

dissimilarity_matrix = squareform(pdist(df[['Feature1', 'Feature2']], metric='euclidean')) # euclidean distance

df_ = pd.DataFrame(dissimilarity_matrix)
df_
# Out:
#            0          1          2          3          4
# 0   0.000000  10.198039  31.240999  46.097722  59.464275
# 1  10.198039   0.000000  24.166092  38.587563  51.613952
# 2  31.240999  24.166092   0.000000  14.866069  28.284271
# 3  46.097722  38.587563  14.866069   0.000000  13.453624
# 4  59.464275  51.613952  28.284271  13.453624   0.000000

# %% [markdown]
# ### Proximity measures for nominal attributes
# The dissimilarity
# between two objects i and j can be computed based on the ratio of mismatches

# %%
from sklearn.metrics import jaccard_score
import matplotlib.pyplot as plt

data = {
    'Instance1': ['Red', 'Square', 'Large', 'dog'],
    'Instance2': ['Blue', 'Circle', 'Small', 'cat']
}

# Convert nominal attributes to binary values (pd.get_dummies)
binary_data = pd.get_dummies(pd.DataFrame(data))
print(binary_data)
jaccard_similarity = jaccard_score(binary_data.iloc[0], binary_data.iloc[1])
jaccard_similarity_1 = jaccard_score(binary_data.iloc[0], binary_data.iloc[0])

for i in range(len(binary_data)):
  print(binary_data.iloc[i], end="\n")

print(f"Jaccard Similarity: {jaccard_similarity}")
print(f"Jaccard Similarity: {jaccard_similarity_1}")
# Out:
#    Instance1_Large  Instance1_Red  Instance1_Square  Instance1_dog  \
# 0            False           True             False          False
# 1            False          False              True          False
# 2             True          False             False          False
# 3            False          False             False           True
#
#    Instance2_Blue  Instance2_Circle  Instance2_Small  Instance2_cat
# 0            True             False            False          False
# 1           False              True            False          False
# 2           False             False             True          False
# 3           False             False            False           True
# Instance1_Large     False
# Instance1_Red        True
# Instance1_Square    False
# Instance1_dog       False
# Instance2_Blue       True
# Instance2_Circle    False
# Instance2_Small     False
# Instance2_cat       False
# Name: 0, dtype: bool
# Instance1_Large     False
# ...

# %% [markdown]
# ### Proximity measures for binary attributes

# %%
import numpy as np
from scipy.spatial.distance import hamming

data ={
    'Instance1': [1, 0, 1, 0, 0],
    'Instance2': [1, 0, 0, 0, 1]
}
arr = np.array([data['Instance1'],data['Instance2']])

distance = hamming(arr[0], arr[1])
print(arr[0])
print(arr[1])
distance
# Out:
# [1 0 1 0 0]
# [1 0 0 0 1]
# 0.4

# %% [markdown]
# ### Dissimilarity of numeric data: Minkowski distance
# d(v, u)= $1\over (Σ(v_i - u_i)^p)^p$

# %%
from scipy.spatial.distance import minkowski
v = [1, 3, 5, 5, 7, 8]
u = [4, 5, 3, 5, 7, 2]

distance = minkowski(u, v, p=2)
distance
# Out:
# 7.280109889280518

# %% [markdown]
# ### Proximity measures for ordinal attributes
# **spearmanr**
#
# ![Screenshot 2024-10-24 145344.png](data:image/png;base64,...)

# %%
import numpy as np
from scipy.stats import spearmanr

data = {
    'Instance1': [4, 3, 2, 1],
    'Instance2': [1, 2, 3, 4]
}

spearman_corr, _ = spearmanr(data['Instance1'], data['Instance2'])
print(_)
print(spearman_corr, end="\n**********\n")

data = {
    'Instance1': [3, 2, 1, 4],
    'Instance2': [2, 1, 4, 3]
}

spearman_corr, _ = spearmanr(data['Instance1'], data['Instance2'])
print(_)
print(spearman_corr, end="\n**********\n")

data = {
    'Instance1': [2, 3, 1, 4],
    'Instance2': [1, 4, 2, 3]
}

spearman_corr, _ = spearmanr(data['Instance1'], data['Instance2'])
print(_)
print(spearman_corr, end="\n**********\n")
# Out:
# 0.0
# -1.0
# **********
# 0.8
# -0.19999999999999998
# **********
# 0.3999999999999999
# 0.6000000000000001
# **********

# %% [markdown]
# ### Dissimilarity for attributes of mixed types
#
# suppose that we have different data types in our data base for measuring dissimilarity what we can do? one solution is gower's distance

# %%
import numpy as np
from scipy.spatial.distance import pdist, squareform
from sklearn.preprocessing import StandardScaler


data = {
    'Numeric': [25, 19, 23, 4, 5],
    'Binary': [1, 0, 1, 1, 0],
    'Nominal': ['A', 'B', 'C', 'D', 'E'],
    'Ordinal': [1, 3, 2, 4, 5]
}


numeric_data = np.array([data['Numeric']]).reshape(-1, 1)
numeric_data = StandardScaler().fit_transform(numeric_data)

binary_data = pd.get_dummies(pd.DataFrame(data['Binary'], columns=['Binary']))

nominal_data = pd.get_dummies(pd.DataFrame(data['Nominal'], columns=['Nominal']))


mixed_data = np.concatenate((numeric_data, binary_data, nominal_data, np.array([data['Ordinal']]).T), axis=1)

distances_oned = pdist(mixed_data, metric='euclidean')
print(f"distances in 1d array:\n{distances_oned}")
distance_sqrd = squareform(distances_oned)
print(f"distances in square form:\n{distance_sqrd}")
# Out:
# distances in 1d array:
# [2.72930427 1.74639635 4.06220347 4.8979608  2.04929276 2.609001
#  2.90604711 3.24090929 4.00523609 2.00311633]
# distances in square form:
# [[0.         2.72930427 1.74639635 4.06220347 4.8979608 ]
#  [2.72930427 0.         2.04929276 2.609001   2.90604711]
#  [1.74639635 2.04929276 0.         3.24090929 4.00523609]
#  [4.06220347 2.609001   3.24090929 0.         2.00311633]
#  [4.8979608  2.90604711 4.00523609 2.00311633 0.        ]]

# %% [markdown]
# ### cosine similarity
# Measures the cosine of the angle between two binary vectors.

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

documents = [
    "apple is a fruit",
    "orange is orange",
    "Python programming is widely used in data science applications."
]

vectorizer = CountVectorizer()
document_matrix = vectorizer.fit_transform(documents)
print(f"doc matrix:\n{document_matrix}")
cosine_similarities = cosine_similarity(document_matrix, document_matrix)
print("Cosine Similarity Matrix:")
print(cosine_similarities)
# Out:
# doc matrix:
#   (0, 0)	1
#   (0, 5)	1
#   (0, 3)	1
#   (1, 5)	1
#   (1, 6)	2
#   (2, 5)	1
#   (2, 8)	1
#   (2, 7)	1
#   (2, 11)	1
#   (2, 10)	1
#   (2, 4)	1
#   (2, 2)	1
#   (2, 9)	1
#   (2, 1)	1
# Cosine Similarity Matrix:
# [[1.         0.25819889 0.19245009]
#  [0.25819889 1.         0.1490712 ]
#  [0.19245009 0.1490712  1.        ]]

# %% [markdown]
# ### Measuring similar distributions: the Kullback-Leibler divergence

# %%
import numpy as np
from scipy.stats import entropy
import matplotlib.pyplot as plt


distribution1 = np.random.normal(0.25, 0.1, 100)
distribution2 = np.random.normal(0.4, 0.2, 100)

plt.figure(figsize=(3,3))
bins = np.linspace(-0.2, 0.5, 50)
plt.hist(distribution1, bins, alpha=0.7, color='blue')
plt.hist(distribution2, bins, alpha=0.7, color='green')
plt.show()
kl_divergence = entropy(distribution1, distribution2)
print(f"Kullback-Leibler Divergence: {kl_divergence}")
# Out:
# Kullback-Leibler Divergence: inf

# %% [markdown]
# ###  Capturing hidden semantics in similarity measures

# %%
from gensim.models import Word2Vec
from sklearn.metrics.pairwise import cosine_similarity

# Example dataset with text documents
documents = [
    "Data mining is an exciting field of study.",
    "Machine learning techniques are used for data analysis.",
    "Python programming is widely used in data science applications.",
    "python and R both are used in Data.",
    "python has a bunch of libraries that help data-scientists."
]

# Tokenize the documents into words
tokenized_documents = [doc.split() for doc in documents]
print(f"sample :{tokenized_documents[0]}")
print(f"tokenized documents length: {len(tokenized_documents)}")
# Train a Word2Vec model on the tokenized documents
model = Word2Vec(tokenized_documents, vector_size=10, window=3, min_count=1, workers=4)
print(f"model: {model}")
# Calculate cosine similarity using word embeddings
embedding_similarity = cosine_similarity([model.wv['python']], [model.wv['R']])
print(f"Cosine Similarity using Word Embeddings: {embedding_similarity[0][0]}")
# Out:
# sample :['Data', 'mining', 'is', 'an', 'exciting', 'field', 'of', 'study.']
# tokenized documents length: 5
# model: Word2Vec<vocab=34, vector_size=10, alpha=0.025>
# Cosine Similarity using Word Embeddings: 0.35378989577293396

# %% [markdown]
# ##  Data quality, data cleaning, and data integration
#
# 1.   Data quality measures
# 2.   Data cleaning
# 3.   Data integration

# %% [markdown]
# ### Data quality measures
# There are many factors comprising **data quality**, including *accuracy, completeness, consistency, timeliness, believability, and interpretability.*

# %%
# missing values
import pandas as pd
import numpy as np

# Example dataset with missing values
data = {
    'Feature1': [10, 15, None, 25, 20],
    'Feature2': [5, None, 8, 12, 10],
    'Feature3': [2, 4, 6, None, 8]
}

df = pd.DataFrame(data)

# Calculate percentage of missing values in each column
feature_missing_values = df.isnull().sum()
print("Missing Values in each feature:")
print(feature_missing_values)

objects_missing_values = np.zeros(len(df))
for i in range(len(df)):
  objects_missing_values[i] += df.iloc[i].isnull().sum()
print()
print("missing values in each object :")
for i in range(len(objects_missing_values)):
  print(f"object {i+1} has {objects_missing_values[i]} missing values")
# Out:
# Missing Values in each feature:
# Feature1    1
# Feature2    1
# Feature3    1
# dtype: int64
#
# missing values in each object :
# object 1 has 0.0 missing values
# object 2 has 1.0 missing values
# object 3 has 1.0 missing values
# object 4 has 1.0 missing values
# object 5 has 0.0 missing values

# %% [markdown]
# ### Data cleaning
#
#
# *   missing values
# *   noisy data
# *   ...

# %%
# handling missing values
# in this strategy we use mode to handle missing values also we can use mean, median, removing rows and columns etc.
import pandas as pd
from sklearn.impute import SimpleImputer

# Example dataset with missing values
data = {
    'Feature1': [10, 15, None, 25, 20],
    'Feature2': [5, None, 8, 12, 10],
    'Feature3': [2, 4, 6, None, 8],
    'Feature4': [10, 4, 8, 25, 10],
}

df = pd.DataFrame(data)
print("first Dataset:")
print(df)
# Handling missing values by mode
imputer = SimpleImputer(strategy='most_frequent')
df_imputed = imputer.fit_transform(df)
# Display the cleaned dataset
print()
print("Cleaned Dataset:")
print(df_imputed)
# Out:
# first Dataset:
#    Feature1  Feature2  Feature3  Feature4
# 0      10.0       5.0       2.0        10
# 1      15.0       NaN       4.0         4
# 2       NaN       8.0       6.0         8
# 3      25.0      12.0       NaN        25
# 4      20.0      10.0       8.0        10
#
# Cleaned Dataset:
# [[10.  5.  2. 10.]
#  [15.  5.  4.  4.]
#  [10.  8.  6.  8.]
#  [25. 12.  2. 25.]
#  [20. 10.  8. 10.]]

# %% [markdown]
# ### Data integration
# process of combining data from different sources into a unified and coherent view. It involves handling inconsistencies, resolving conflicts, and creating a merged dataset that can be used for analysis and mining.

# %%
import pandas as pd

# Example datasets with a common key
data1 = {'ID': [1, 2, 3, 4], 'Name': ['Alice', 'Bob', 'Charlie', 'kyle']}
data2 = {'ID': [1, 2, 3], 'Age': [25, 30, 22]}

df1 = pd.DataFrame(data1)
df2 = pd.DataFrame(data2)

print("dataframe 1:")
print(df1)

print()
print("dataframe 2:")
print(df2)

# Merge datasets on the common key 'ID'
merged_df = pd.merge(df1, df2, on='ID', how='outer')

# handling missing value in merged DataFrame
merged_df['Age'] = merged_df['Age'].fillna(round(merged_df['Age'].mean(), 0))

# Display the merged dataset
print()
print("Merged Dataset:")
print(merged_df)
# Out:
# dataframe 1:
#    ID     Name
# 0   1    Alice
# 1   2      Bob
# 2   3  Charlie
# 3   4     kyle
#
# dataframe 2:
#    ID  Age
# 0   1   25
# 1   2   30
# 2   3   22
#
# Merged Dataset:
#    ID     Name   Age
# 0   1    Alice  25.0
# 1   2      Bob  30.0
# 2   3  Charlie  22.0
# 3   4     kyle  26.0

# %% [markdown]
# ## Data transformation
#
#
# 1.   Normalization
# 2.   Discretization
# 3.   Data compression

# %% [markdown]
# ### Normalization
# **Normalization** involves transforming the data
# to fall within a smaller or common range such as [−1, 1] or [0, 1].
#
# types of normalization:
# *   Min-Max normalization
# *   z-score normalization
# *   ...

# %%
# min-max normalizaion
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

data = [10, 32, 43, 45, 65, 45, 87, 123, 122, 99]
df = pd.DataFrame(data, columns=["Data"])
print(df.head())
print()

plt.figure(figsize=(2, 2))
plt.hist(data)
plt.title("data_histogram")
plt.show()

scaler = MinMaxScaler()
normalized_data = scaler.fit_transform(df)
normalized_data_df = pd.DataFrame(normalized_data, columns=["normalized_Data"])
print(normalized_data_df.head())
print()

plt.figure(figsize=(2, 2))
plt.hist(normalized_data)
plt.title("normalized_data_histogram")
plt.show()
# Out:
#    Data
# 0    10
# 1    32
# 2    43
# 3    45
# 4    65
#    normalized_Data
# 0         0.000000
# 1         0.194690
# 2         0.292035
# 3         0.309735
# 4         0.486726

# %%
# z-score normalization
from scipy.stats import zscore

data = [10, 32, 43, 45, 65, 45, 87, 123, 122, 99]
plt.figure(figsize=(2, 2))
plt.hist(data)
plt.title("data_histogram")
plt.show()


normalized_data = zscore(data)
plt.figure(figsize=(2, 2))
plt.hist(normalized_data)
plt.title("normalized_data_histogram")
plt.show()

# %% [markdown]
# ### Discretization
# **Discretization** is a data preprocessing technique that involves converting continuous numerical attributes into discrete categories or bins.

# %%
import pandas as pd
from sklearn.preprocessing import KBinsDiscretizer

# Example dataset with a continuous numerical feature
data = {
    'Age': [22, 35, 42, 28, 55, 48, 33, 40, 60, 70]
}

df = pd.DataFrame(data)
print(df)

# Apply Equal Width Binning to discretize the 'Age' feature
discretizer = KBinsDiscretizer(n_bins=5, encode='ordinal', strategy='kmeans')
discretized_data = discretizer.fit_transform(df)

# Display the discretized dataset
discretized_df = pd.DataFrame(discretized_data, columns=df.columns)
print("Discretized Dataset:")
print(discretized_df)
# Out:
#    Age
# 0   22
# 1   35
# 2   42
# 3   28
# 4   55
# 5   48
# 6   33
# 7   40
# 8   60
# 9   70
# Discretized Dataset:
#    Age
# 0  0.0
# 1  1.0
# 2  2.0
# 3  0.0
# 4  3.0
# 5  2.0
# 6  1.0
# 7  1.0
# 8  3.0
# 9  4.0

# %% [markdown]
# ### Data compression
# In data compression, transformations are applied so as to obtain a reduced or **compressed** representation
# of the original data.

# %% [markdown]
# ## Dimensionality reduction
#
#
# 1.   Principal components analysis (PCA)
# 2.   Attribute subset selection
# 3.   Nonlinear dimensionality reduction methods

# %% [markdown]
# ### PCA:
# **PCA** is a dimensionality reduction technique used to transform a dataset into a lower-dimensional space while retaining as much of the original variance as possible. PCA identifies the principal components, which are orthogonal vectors that capture the directions of maximum variance in the data.

# %%
# PCA

# libraries
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.datasets import load_wine # our dataset
import matplotlib.pyplot as plt

# %% [markdown]
# #### Dataset
# Wine Dataset Contains 13 features describing different types of wine.

# %%
wine = load_wine()
df = pd.DataFrame(wine.data, columns=wine.feature_names)
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline
# ...

# %% [markdown]
# #### pre-process on data

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
data_scaled = scaler.fit_transform(df)
print(data_scaled[1])
# Out:
# [ 0.24628963 -0.49941338 -0.82799632 -2.49084714  0.01814502  0.56864766
#   0.73362894 -0.82071924 -0.54472099 -0.29332133  0.40605066  1.1134493
#   0.96524152 -1.21394365]

# %% [markdown]
# #### apply pca (let number of components be 3)

# %%
pca = PCA(n_components=3)
principal_components = pca.fit_transform(data_scaled)
print(f"principal component for a sample: {principal_components[1]}")

target = wine.target
pcs_df = pd.DataFrame(principal_components, columns=['PC1', 'PC2', 'PC3'])
pcs_df['target'] = target
pcs_df.head()
#   print(set(target))
# Out:
# principal component for a sample: [-2.52885806 -0.33001925 -2.02670665]
#         PC1       PC2       PC3  target
# 0 -3.522934  1.453098 -0.164795       0
# 1 -2.528858 -0.330019 -2.026707       0
# 2 -2.785029  1.036936  0.983238       0
# 3 -3.922588  2.768210 -0.174968       0
# 4 -1.407511  0.867773  2.025829       0

# %% [markdown]
# #### plot

# %%
targets = [0, 1, 2]
colors = ['r', 'g', 'b']
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(projection='3d')

for target, color in zip(targets, colors):
    indices_to_keep = pcs_df['target'] == target
    ax.scatter(pcs_df.loc[indices_to_keep, 'PC1'],
                pcs_df.loc[indices_to_keep, 'PC2'],
                pcs_df.loc[indices_to_keep, 'PC3'],
                c=color,
                label=target,
                alpha=0.7)

ax.set_xlabel('Principal Component 1')
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('principal Component 3')
plt.title('Principal Components Analysis')
plt.legend()
plt.show()

# %% [markdown]
# #### apply pca (by number of components 2)

# %%
pca = PCA(n_components=2)
principal_components = pca.fit_transform(data_scaled)
print(f"principal component for a sample: {principal_components[1]}")

target = wine.target
pcs_df = pd.DataFrame(principal_components, columns=['PC1', 'PC2'])
pcs_df['target'] = target
pcs_df.head()
# Out:
# principal component for a sample: [-2.52885806 -0.33001925]
#         PC1       PC2  target
# 0 -3.522934  1.453098       0
# 1 -2.528858 -0.330019       0
# 2 -2.785029  1.036936       0
# 3 -3.922588  2.768210       0
# 4 -1.407511  0.867773       0

# %% [markdown]
# #### plot

# %%
targets = [0, 1, 2]
colors = ['r', 'g', 'b']
fig = plt.figure(figsize=(8, 6))

for target, color in zip(targets, colors):
    indices_to_keep = pcs_df['target'] == target
    plt.scatter(pcs_df.loc[indices_to_keep, 'PC1'],
                pcs_df.loc[indices_to_keep, 'PC2'],
                c=color,
                label=target,
                alpha=0.7)

plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('Principal Components Analysis')
plt.legend()
plt.show()
